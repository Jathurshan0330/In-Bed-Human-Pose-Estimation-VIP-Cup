# %%
from google.colab import drive
# %load_ext autoreload
# %autoreload 2

drive.mount('/content/gdrive') #inbedpose

# !cp "/content/gdrive/My Drive/CODES_inbedpose_estimation/transfer_modules.py" '/content'
# !cp -r '/content/gdrive/MyDrive/In-Bed-Human-Pose-Estimation(VIP-CUP)' '/content'
# Out:
# Mounted at /content/gdrive

# %%
from transfer_modules import send_modules, recieve_modules
recieve_modules()
#send_modules()
# Out:
# modules send to : /content/gdrive/My Drive/CODES_inbedpose_estimation/inbed_pose_estimation/modules

# %%
# %%capture
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# %cd pytorch-CycleGAN-and-pix2pix
# !pip install -r requirements.txt

# %%
# !cp -r '/content/gdrive/MyDrive/In-Bed-Human-Pose-Estimation(VIP-CUP)/CycleGAN_unpaired/checkpoints' .
# !cp './checkpoints/InbedPose_CyleGAN/latest_net_G_B.pth' './checkpoints/InbedPose_CyleGAN/latest_net_G.pth'

# %%
# !python /content/inbed_pose_estimation/modules/cyclegan/cyclegan_generate_covered.py --remove_folder "cyclegan_cover1"
# !python /content/inbed_pose_estimation/modules/cyclegan/cyclegan_generate_covered.py --model_name "InbedPose_CyleGAN" --result_folder "cyclegan_cover1" --resize_shape "(120, 160)"
